# %%
run -i MECH530_main.py
# Out:
# PLYBOOK (READ FROM EXCEL FILE AND SUMMARIZED HERE)
#
# The laminate is given by the following plybook where the highest ply number '17' indicates the top layer, while the first ply number '1' indicates the bottom layer.
#
# Unique Ply #, Fiber/Matrix, Orientation, Thickness
#                              (degrees)      (mm)
#     17         T300/N5208         0         0.125
#     16         T300/N5208        10         0.125
#     15         T300/N5208        17         0.125
#     14         T300/N5208       -17         0.125
#     13         T300/N5208        37         0.125
#     12         T300/N5208       -37         0.125
#     11         T300/N5208        35         0.125
#     10         T300/N5208        13         0.125
#      9               CORE         0         1.500
#      8         T300/N5208        13         0.125
#      7         T300/N5208        35         0.125
#      6         T300/N5208       -37         0.125
# ...

# %%
stress_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d1aae08e3a18> in <module>()
# ----> 1 stress_df
#
# NameError: name 'stress_df' is not defined

# %%
failure_df
# Out:
#      Ply  Angle    max_FT  max_FC    max_MT  max_MC     max_S       (+)  \
# Pos
# TOP    4     52  9.868536       0  1.475111       0  3.738721  2.454564
# BOT    4     52  9.868536       0  1.475111       0  3.738721  2.454564
# TOP    3    -52  9.868536       0  1.475111       0  3.738721  2.454564
# BOT    3    -52  9.868536       0  1.475111       0  3.738721  2.454564
# TOP    2    -52  9.868536       0  1.475111       0  3.738721  2.454564
# BOT    2    -52  9.868536       0  1.475111       0  3.738721  2.454564
# TOP    1     52  9.868536       0  1.475111       0  3.738721  2.454564
# BOT    1     52  9.868536       0  1.475111       0  3.738721  2.454564
#
#          (-)   hash_FT  hash_FC  hash_MT  hash_MC
# Pos
# TOP -2.59519  3.496225        0  1.37217        0
# BOT -2.59519  3.496225        0  1.37217        0
# TOP -2.59519  3.496225        0  1.37217        0
# BOT -2.59519  3.496225        0  1.37217        0
# TOP -2.59519  3.496225        0  1.37217        0
# ...

# %%
print stress_df.to_latex()
# Out:
# \begin{tabular}{lrrrrrrrrrrr}
# \toprule
# {} &  Ply &  Angle &     e\_1 &       e\_2 &  e\_3 &      e\_x &       e\_y &       e\_z &  Sigma\_x (GPa) &  Sigma\_y (GPa) &  Sigma\_z (GPa) \\
# \midrule
# Pos &      &        &         &           &      &          &           &           &                &                &                \\
# TOP &    4 &     52 & -0.0007 &  0.003375 &    0 &  0.00183 &  0.000844 &  0.003954 &       0.141865 &       0.008135 &       0.009094 \\
# BOT &    4 &     52 & -0.0007 &  0.003375 &    0 &  0.00183 &  0.000844 &  0.003954 &       0.141865 &       0.008135 &       0.009094 \\
# TOP &    3 &    -52 & -0.0007 &  0.003375 &    0 &  0.00183 &  0.000844 & -0.003954 &       0.141865 &       0.008135 &      -0.009094 \\
# BOT &    3 &    -52 & -0.0007 &  0.003375 &    0 &  0.00183 &  0.000844 & -0.003954 &       0.141865 &       0.008135 &      -0.009094 \\
# ...

# %%
print failure_df.to_latex(float_format=lambda x:"%.3f" % x)
# Out:
# \begin{tabular}{lrrrrrrrrrrrrr}
# \toprule
# {} &   Ply &   Angle &  max\_FT &  max\_FC &  max\_MT &  max\_MC &  max\_S &   (+) &    (-) &  hash\_FT &  hash\_FC &  hash\_MT &  hash\_MC \\
# \midrule
# Pos &       &         &         &         &         &         &        &       &        &          &          &          &          \\
# TOP & 4.000 &  52.000 &   9.869 &   0.000 &   1.475 &   0.000 &  3.739 & 2.455 & -2.595 &    3.496 &    0.000 &    1.372 &    0.000 \\
# BOT & 4.000 &  52.000 &   9.869 &   0.000 &   1.475 &   0.000 &  3.739 & 2.455 & -2.595 &    3.496 &    0.000 &    1.372 &    0.000 \\
# TOP & 3.000 & -52.000 &   9.869 &   0.000 &   1.475 &   0.000 &  3.739 & 2.455 & -2.595 &    3.496 &    0.000 &    1.372 &    0.000 \\
# BOT & 3.000 & -52.000 &   9.869 &   0.000 &   1.475 &   0.000 &  3.739 & 2.455 & -2.595 &    3.496 &    0.000 &    1.372 &    0.000 \\
# ...
