# %%
run -i MECH530_main.py
# Out:
# PLYBOOK (READ FROM EXCEL FILE AND SUMMARIZED HERE)
#
# The laminate is given by the following plybook where the highest ply number '19' indicates the top layer, while the first ply number '1' indicates the bottom layer.
#
# Unique Ply #, Fiber/Matrix, Orientation, Thickness
#                              (degrees)      (mm)
#     19         T300/N5208        90         0.125
#     18         T300/N5208        90         0.125
#     17         T300/N5208        90         0.125
#     16         T300/N5208        45         0.125
#     15         T300/N5208        45         0.125
#     14         T300/N5208        45         0.125
#     13         T300/N5208         0         0.125
#     12         T300/N5208         0         0.125
#     11         T300/N5208         0         0.125
#     10               CORE         0         3.175
#      9         T300/N5208         0         0.125
#      8         T300/N5208         0         0.125
# ...

# %%
#stress_df1

# %%
#failure_df1

# %%
print stress_df1.to_latex()
# Out:
# \begin{tabular}{lrrrrrrrrrrr}
# \toprule
# {} &  Ply &  Angle &      e\_1 &       e\_2 &       e\_3 &       e\_x &       e\_y &       e\_z &  Sigma\_x (GPa) &  Sigma\_y (GPa) &  Sigma\_z (GPa) \\
# \midrule
# Pos &      &        &          &           &           &           &           &           &                &                &                \\
# TOP &   19 &     90 & -0.00002 & -0.000016 &  0.000025 & -0.000016 & -0.000020 & -0.000025 &      -0.003013 &      -0.000252 &      -0.000182 \\
# BOT &   19 &     90 & -0.00002 & -0.000016 &  0.000025 & -0.000016 & -0.000020 & -0.000025 &      -0.003013 &      -0.000252 &      -0.000182 \\
# TOP &   18 &     90 & -0.00002 & -0.000016 &  0.000025 & -0.000016 & -0.000020 & -0.000025 &      -0.003013 &      -0.000252 &      -0.000182 \\
# BOT &   18 &     90 & -0.00002 & -0.000016 &  0.000025 & -0.000016 & -0.000020 & -0.000025 &      -0.003013 &      -0.000252 &      -0.000182 \\
# ...

# %%
print failure_df1.to_latex(float_format=lambda x:"%.3f" % x)
# Out:
# \begin{tabular}{lrrrrrrrrrrrrrl}
# \toprule
# {} &    Ply &  Angle &  max\_FT &   max\_FC &  max\_MT &   max\_MC &    max\_S &     (+) &      (-) &  hash\_FT &  hash\_FC &  hash\_MT &  hash\_MC &  Pos \\
# \midrule
# 0  & 19.000 & 90.000 &   0.000 &  497.802 &   0.000 &  974.505 &  373.382 & 561.906 & -141.555 &    0.000 &  497.802 &    0.000 &  435.707 &  TOP \\
# 1  & 19.000 & 90.000 &   0.000 &  497.802 &   0.000 &  974.505 &  373.382 & 561.906 & -141.555 &    0.000 &  497.802 &    0.000 &  435.707 &  BOT \\
# 2  & 18.000 & 90.000 &   0.000 &  497.802 &   0.000 &  974.505 &  373.382 & 561.906 & -141.555 &    0.000 &  497.802 &    0.000 &  435.707 &  TOP \\
# 3  & 18.000 & 90.000 &   0.000 &  497.802 &   0.000 &  974.505 &  373.382 & 561.906 & -141.555 &    0.000 &  497.802 &    0.000 &  435.707 &  BOT \\
# 4  & 17.000 & 90.000 &   0.000 &  497.802 &   0.000 &  974.505 &  373.382 & 561.906 & -141.555 &    0.000 &  497.802 &    0.000 &  435.707 &  TOP \\
# ...
