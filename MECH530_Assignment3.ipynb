# %%
run MECH530_main.py
# Out:
# PLYBOOK (READ FROM EXCEL FILE AND SUMMARIZED HERE)
#
# The laminate is given by the following plybook where the highest ply number '14' indicates the top layer, while the first ply number '1' indicates the bottom layer.
#
# Unique Ply #, Fiber/Matrix, Orientation, Thickness
#                              (degrees)      (mm)
#     14         T300/N5208        10         0.125
#     13         T300/N5208       -10         0.125
#     12         T300/N5208        90         0.125
#     11         T300/N5208         0         0.125
#     10         T300/N5208         0         0.125
#      9         T300/N5208        50         0.125
#      8         T300/N5208       -50         0.125
#      7         T300/N5208       -50         0.125
#      6         T300/N5208        50         0.125
#      5         T300/N5208         0         0.125
#      4         T300/N5208         0         0.125
#      3         T300/N5208        90         0.125
# ...
