# %%
run -i MECH530_main.py
# Out:
# PLYBOOK (READ FROM EXCEL FILE AND SUMMARIZED HERE)
#
# The laminate is given by the following plybook where the highest ply number '15' indicates the top layer, while the first ply number '1' indicates the bottom layer.
#
# Unique Ply #, Fiber/Matrix, Orientation, Thickness
#                              (degrees)      (mm)
#     15             SE84LV         0         0.290
#     14        BIAX-SE84LV        45         0.145
#     13        BIAX-SE84LV       -45         0.145
#     12        BIAX-SE84LV        45         0.145
#     11        BIAX-SE84LV       -45         0.145
#     10        BIAX-SE84LV        45         0.145
#      9        BIAX-SE84LV       -45         0.145
#      8               CORE         0         3.175
#      7        BIAX-SE84LV       -45         0.145
#      6        BIAX-SE84LV        45         0.145
#      5        BIAX-SE84LV       -45         0.145
#      4        BIAX-SE84LV        45         0.145
# ...

# %%
#stress_df2

# %%
#failure_df1

# %%
print stress_df1.to_latex()
# Out:
# \begin{tabular}{lrrrrrrrrrrr}
# \toprule
# {} &  Ply &  Angle &       e\_1 &       e\_2 &  e\_3 &       e\_x &       e\_y &       e\_z &  Sigma\_x (GPa) &  Sigma\_y (GPa) &  Sigma\_z (GPa) \\
# \midrule
# Pos &      &        &           &           &      &           &           &           &                &                &                \\
# TOP &   15 &      0 & -0.000011 & -0.000027 &    0 & -0.000011 & -0.000027 &  0.000000 &      -0.001664 &      -0.000306 &       0.000000 \\
# BOT &   15 &      0 & -0.000011 & -0.000027 &    0 & -0.000011 & -0.000027 &  0.000000 &      -0.001664 &      -0.000306 &       0.000000 \\
# TOP &   14 &     45 & -0.000011 & -0.000027 &    0 & -0.000019 & -0.000019 & -0.000017 &      -0.002735 &      -0.000291 &      -0.000071 \\
# BOT &   14 &     45 & -0.000011 & -0.000027 &    0 & -0.000019 & -0.000019 & -0.000017 &      -0.002735 &      -0.000291 &      -0.000071 \\
# ...

# %%
print failure_df1.to_latex(float_format=lambda x:"%.3f" % x)
# Out:
# \begin{tabular}{lrrrrrrrrrrrrrl}
# \toprule
# {} &    Ply &   Angle &  max\_FT &  max\_FC &  max\_MT &  max\_MC &    max\_S &     (+) &      (-) &  hash\_FT &  hash\_FC &  hash\_MT &  hash\_MC &  Pos \\
# \midrule
# 0  & 15.000 &   0.000 &   0.000 & 754.721 &   0.000 & 660.045 &      inf & 710.094 & -203.293 &    0.000 &  754.721 &    0.000 &  660.045 &  TOP \\
# 1  & 15.000 &   0.000 &   0.000 & 754.721 &   0.000 & 660.045 &      inf & 710.094 & -203.293 &    0.000 &  754.721 &    0.000 &  660.045 &  BOT \\
# 2  & 14.000 &  45.000 &   0.000 & 459.247 &   0.000 & 695.262 & 1083.205 & 644.915 & -229.149 &    0.000 &  459.247 &    0.000 &  607.837 &  TOP \\
# 3  & 14.000 &  45.000 &   0.000 & 459.247 &   0.000 & 695.262 & 1083.205 & 644.915 & -229.149 &    0.000 &  459.247 &    0.000 &  607.837 &  BOT \\
# 4  & 13.000 & -45.000 &   0.000 & 459.247 &   0.000 & 695.262 & 1083.205 & 644.915 & -229.149 &    0.000 &  459.247 &    0.000 &  607.837 &  TOP \\
# ...

# %%
print stress_df2.to_latex()
# Out:
# \begin{tabular}{lrrrrrrrrrrr}
# \toprule
# {} &  Ply &  Angle &       e\_1 &       e\_2 &       e\_3 &       e\_x &       e\_y &       e\_z &  Sigma\_x (GPa) &  Sigma\_y (GPa) &  Sigma\_z (GPa) \\
# \midrule
# Pos &      &        &           &           &           &           &           &           &                &                &                \\
# TOP &   15 &      0 &  0.001065 & -0.000728 & -0.000019 &  0.001065 & -0.000728 & -0.000019 &       0.140136 &       0.000870 &      -0.000083 \\
# BOT &   15 &      0 &  0.000952 & -0.000651 & -0.000017 &  0.000952 & -0.000651 & -0.000017 &       0.125345 &       0.000778 &      -0.000074 \\
# TOP &   14 &     45 &  0.000952 & -0.000651 & -0.000017 &  0.000142 &  0.000159 & -0.001604 &       0.020360 &       0.002298 &      -0.006896 \\
# BOT &   14 &     45 &  0.000896 & -0.000613 & -0.000016 &  0.000133 &  0.000150 & -0.001509 &       0.019158 &       0.002162 &      -0.006489 \\
# ...

# %%
print failure_df2.to_latex(float_format=lambda x:"%.3f" % x)
# Out:
# \begin{tabular}{lrrrrrrrrrrrrrl}
# \toprule
# {} &    Ply &   Angle &  max\_FT &  max\_FC &  max\_MT &  max\_MC &    max\_S &    (+) &     (-) &  hash\_FT &  hash\_FC &  hash\_MT &  hash\_MC &  Pos \\
# \midrule
# 0  & 15.000 &   0.000 &  20.601 &   0.000 &  60.953 &   0.000 &  928.751 & 20.485 & -10.025 &   20.596 &    0.000 &   60.822 &    0.000 &  TOP \\
# 1  & 15.000 &   0.000 &  23.032 &   0.000 &  68.146 &   0.000 & 1038.349 & 22.903 & -11.208 &   23.027 &    0.000 &   68.000 &    0.000 &  BOT \\
# 2  & 14.000 &  45.000 & 141.800 &   0.000 &  23.067 &   0.000 &   11.166 &  9.642 & -12.361 &   11.132 &    0.000 &   10.050 &    0.000 &  TOP \\
# 3  & 14.000 &  45.000 & 150.691 &   0.000 &  24.513 &   0.000 &   11.866 & 10.246 & -13.137 &   11.830 &    0.000 &   10.681 &    0.000 &  BOT \\
# 4  & 13.000 & -45.000 & 135.792 &   0.000 &  24.863 &   0.000 &   11.866 & 10.333 & -13.042 &   11.821 &    0.000 &   10.709 &    0.000 &  TOP \\
# ...
